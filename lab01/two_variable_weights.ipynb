# %%
import pandas as pd
import seaborn as sb

datos = pd.read_csv("pesos.csv")

# %%
datos.describe()
# Out:
#            altura       peso
# count    9.000000   9.000000
# mean   162.103333  64.875556
# std     23.008653  25.301177
# min    120.400000  23.260000
# 25%    150.000000  51.300000
# 50%    166.000000  68.800000
# 75%    180.000000  85.100000
# max    190.000000  97.100000

# %%
datos.head()
# Out:
#    altura   peso
# 0  120.40  23.26
# 1  136.53  32.22
# 2  150.00  51.30
# 3  160.00  62.90
# 4  166.00  68.80

# %%
datos.hist()
# Out:
# array([[<Axes: title={'center': 'altura'}>,
#         <Axes: title={'center': 'peso'}>]], dtype=object)

# %%
import seaborn as sb


sb.scatterplot(x="altura",y="peso",data=datos,hue="altura")
# Out:
# <Axes: xlabel='altura', ylabel='peso'>

# %%
#Caracteristica x, etiqueta y
x= datos["altura"]
y= datos["peso"]

# %%
x.values
x_procesada = x.values.reshape(-1,1)
y_procesada = y.values.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression

modelo = LinearRegression()

modelo.fit(x_procesada,y_procesada)
# Out:
# LinearRegression()

# %%
altura = 167
prediccion=modelo.predict([[altura]])
[[degg]] = prediccion
print(f'para {altura} cm de altura, lo reomendable es pesar {round(degg)} Kg')
# Out:
# para 167 cm de altura, lo reomendable es pesar 70 Kg
